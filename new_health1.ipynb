# %% [markdown]
# <a href="https://colab.research.google.com/github/C026-01-0774-2023-NewtonOlando/new_health/blob/main/new_health1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5ca8e8c-89bc-42a6-8022-2a6645f128bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5ca8e8c-89bc-42a6-8022-2a6645f128bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Path to our dataset in Google Drive
file_path = "/content/drive/MyDrive/Disease_ML_Project/datasets/diseases_synthetic_symptoms.csv"

# Load the dataset
df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (4446, 3)

# %%
df.head()
# Out:
#    Disease                                           Symptoms  Data_Type
# 0  Malaria                                     nausea, chills  SYNTHETIC
# 1  Malaria                  fatigue, nausea, chills, vomiting  SYNTHETIC
# 2  Malaria                   fever, nausea, sweating, fatigue  SYNTHETIC
# 3  Malaria  nausea, fever, fatigue, chills, headache, vomi...  SYNTHETIC
# 4  Malaria                 chills, nausea, sweating, vomiting  SYNTHETIC

# %%
print("Columns:")
for i, column in enumerate(df.columns):
    print(i, "→", column)
# Out:
# Columns:
# 0 → Disease
# 1 → Symptoms
# 2 → Data_Type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446 entries, 0 to 4445
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Disease    4446 non-null   object
#  1   Symptoms   4446 non-null   object
#  2   Data_Type  4446 non-null   object
# dtypes: object(3)
# memory usage: 104.3+ KB

# %%
print(df.isnull().sum())
# Out:
# Disease      0
# Symptoms     0
# Data_Type    0
# dtype: int64

# %%
print("Number of unique diseases:", df["Disease"].nunique())

print("\nDiseases:")
print(df["Disease"].unique())
# Out:
# Number of unique diseases: 112
#
# Diseases:
# ['Malaria' 'Tuberculosis' 'COVID-19' 'Influenza' 'Common Cold' 'HIV/AIDS'
#  'Hepatitis B' 'Hepatitis C' 'Cholera' 'Typhoid Fever' 'Dengue Fever'
#  'Ebola Virus Disease' 'Measles' 'Chickenpox' 'Meningitis (Bacterial)'
#  'Pneumonia' 'Rabies' 'Tetanus' "Leprosy (Hansen's Disease)"
#  'Zika Virus Disease' 'Yellow Fever' 'Diphtheria'
#  'Whooping Cough (Pertussis)' 'Polio' 'Mumps' 'Rubella'
#  'COVID-19 (Long COVID)' 'Lyme Disease' 'Anthrax' 'Chikungunya'
#  'Toxoplasmosis' 'Schistosomiasis' 'Candidiasis' 'Histoplasmosis'
#  'Ringworm (Dermatophytosis)' 'Ascariasis' 'Giardiasis'
#  'Chronic Kidney Disease' 'Type 2 Diabetes' 'Hypertension' 'Asthma'
#  'Bubonic Plague' 'Marburg Virus Disease' 'Lassa Fever'
#  'Nipah Virus Infection' 'Hantavirus Pulmonary Syndrome' 'Q Fever'
#  'Brucellosis' 'Leptospirosis'
#  'African Trypanosomiasis (Sleeping Sickness)' 'Chagas Disease'
# ...

# %%
disease_counts = df["Disease"].value_counts()

print(disease_counts)
# Out:
# Disease
# Malaria               50
# Asthma                50
# Giardiasis            50
# Chikungunya           50
# Glaucoma              50
#                       ..
# Gonorrhea             30
# Multiple Sclerosis    30
# Trichomoniasis        30
# Prostate Cancer       30
# Heart Failure         30
# Name: count, Length: 112, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

disease_counts.plot(kind="bar")

plt.title("Number of Samples per Disease")
plt.xlabel("Disease")
plt.ylabel("Number of Samples")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
pd.set_option("display.max_colwidth", None)

df[["Disease", "Symptoms"]].head(20)
# Out:
#     Disease                                            Symptoms
# 0   Malaria                                      nausea, chills
# 1   Malaria                   fatigue, nausea, chills, vomiting
# 2   Malaria                    fever, nausea, sweating, fatigue
# 3   Malaria  nausea, fever, fatigue, chills, headache, vomiting
# 4   Malaria                  chills, nausea, sweating, vomiting
# 5   Malaria                            fever, fatigue, sweating
# 6   Malaria                 vomiting, nausea, sweating, fatigue
# 7   Malaria                vomiting, nausea, headache, sweating
# 8   Malaria            fever, chills, sweating, fatigue, nausea
# 9   Malaria                 fatigue, chills, sweating, headache
# 10  Malaria                          nausea, headache, sweating
# 11  Malaria                 fatigue, chills, vomiting, headache
# 12  Malaria           sweating, nausea, chills, headache, fever
# 13  Malaria                           fever, sweating, vomiting
# ...

# %%
df[["Disease", "Symptoms"]].sample(20, random_state=42)
# Out:
#                                               Disease  \
# 3286                                Colorectal Cancer
# 1550                                  Type 2 Diabetes
# 1103                                     Lyme Disease
# 2301                                         Syphilis
# 1001                                          Rubella
# 2446                             Herpes Simplex (HSV)
# 680                                            Rabies
# 132                                         Influenza
# 4036                          Coronary Artery Disease
# 2498                                          Scabies
# 3154                                     Osteoporosis
# 2107                 Onchocerciasis (River Blindness)
# 3246                                    Breast Cancer
# 3892  Attention-Deficit/Hyperactivity Disorder (ADHD)
# 3463                                         Leukemia
# 1833                    Hantavirus Pulmonary Syndrome
# ...

# %%
# Combine all symptom text into one string
all_symptoms = ", ".join(df["Symptoms"].astype(str))

# Split by commas
symptom_list = [s.strip().lower() for s in all_symptoms.split(",")]

# Remove duplicates
unique_symptoms = sorted(set(symptom_list))

print("Number of unique symptoms:", len(unique_symptoms))

print("\nSymptoms:")
for symptom in unique_symptoms:
    print(symptom)
# Out:
# Number of unique symptoms: 1383
#
# Symptoms:
# 'whooping' sound
# abdominal cramps
# abdominal pain
# abnormal vaginal bleeding
# agitation
# alternating episodes of mania and depression
# anemia
# arm/jaw pain
# avoidance behaviors
# back pain
# balance problems
# birth defects if infected during pregnancy
# bleeding
# bleeding in severe cases
# bleeding tendency
# blindness (chronic)
# bloating
# blood in stool
# blood in urine
# blood in urine/stool (chronic)
# blurred vision
# blurred/cloudy vision
# bone deformities
# brain fog
# breast lump
# bullseye rash
# burrow tracks in skin
# can lead to cervical/other cancers
# changes in bowel habits
# changes in breast shape/skin
# changes in energy/activity
# changes in urination
# characteristic facial features
# chest discomfort (inhalation)
# chest pain
# chest pain (often mild or asymptomatic)
# chest tightness
# chills
# chronic cough
# circular rash with clear center
# cognitive decline
# color changes on skin
# confusion
# ...

# %%
# Count duplicated symptom combinations
duplicate_count = df["Symptoms"].duplicated().sum()

print("Duplicate symptom combinations:", duplicate_count)
print("Total rows:", len(df))
print("Unique symptom combinations:", df["Symptoms"].nunique())
# Out:
# Duplicate symptom combinations: 103
# Total rows: 4446
# Unique symptom combinations: 4343

# %%
duplicates = df[df["Symptoms"].duplicated(keep=False)].sort_values("Symptoms")

duplicates[["Disease", "Symptoms"]].head(30)
# Out:
#                       Disease  \
# 1252          Schistosomiasis
# 2253       Hookworm Infection
# 3500        Pancreatic Cancer
# 289               Hepatitis B
# 3501        Pancreatic Cancer
# 380             Typhoid Fever
# 3401             Liver Cancer
# 1445               Ascariasis
# 3502        Pancreatic Cancer
# 3375             Liver Cancer
# 827              Yellow Fever
# 1766              Lassa Fever
# 3217              Lung Cancer
# 4025  Coronary Artery Disease
# 20                    Malaria
# 162                 Influenza
# 139                 Influenza
# 95                   COVID-19
# 124                 Influenza
# 2704    Legionnaires' Disease
# 282               Hepatitis B
# 297               Hepatitis C
# 2335                Gonorrhea
# 2365                Chlamydia
# 2199               Amoebiasis
# 2846     Rheumatoid Arthritis
# 310               Hepatitis C
# 2248       Hookworm Infection
# 2240       Hookworm Infection
# 3022      Sickle Cell Disease
#
# ...

# %%
df["Symptom_Count"] = df["Symptoms"].str.split(",").str.len()

print(df["Symptom_Count"].describe())
# Out:
# count    4446.000000
# mean        2.529690
# std         0.880942
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Symptom_Count, dtype: float64

# %%
print(df["Symptom_Count"].value_counts().sort_index())
# Out:
# Symptom_Count
# 1     378
# 2    2020
# 3    1463
# 4     493
# 5      84
# 6       8
# Name: count, dtype: int64

# %%
df = df.drop(columns=["Symptom_Count"])

print(df.columns)
# Out:
# Index(['Disease', 'Symptoms', 'Data_Type'], dtype='object')

# %%
X = df["Symptoms"]
y = df["Disease"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (4446,)
# y shape: (4446,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Training samples: 3556
# Testing samples: 890

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    lowercase=True,
    ngram_range=(1, 2)
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("Training feature matrix:", X_train_tfidf.shape)
print("Testing feature matrix:", X_test_tfidf.shape)
# Out:
# Training feature matrix: (3556, 3018)
# Testing feature matrix: (890, 3018)

# %%
from sklearn.linear_model import LogisticRegression

# Create the model
logistic_model = LogisticRegression(
    max_iter=2000,
    random_state=42
)

# Train the model
logistic_model.fit(X_train_tfidf, y_train)

print("✅ Logistic Regression trained successfully!")
# Out:
# ✅ Logistic Regression trained successfully!

# %%
y_pred = logistic_model.predict(X_test_tfidf)

print("Predictions completed!")
print("Number of predictions:", len(y_pred))
# Out:
# Predictions completed!
# Number of predictions: 890

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 0.9135
# Accuracy: 91.35%

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_test,
    y_pred,
    zero_division=0
)

print(report)
# Out:
#                                                  precision    recall  f1-score   support
#
#     African Trypanosomiasis (Sleeping Sickness)       1.00      0.50      0.67         6
#                             Alzheimer's Disease       1.00      1.00      1.00        10
#                                      Amoebiasis       1.00      0.67      0.80         6
#                                Anorexia Nervosa       1.00      1.00      1.00         8
#                                         Anthrax       1.00      1.00      1.00         8
#                                      Ascariasis       1.00      0.67      0.80         9
#                                          Asthma       0.91      1.00      0.95        10
# Attention-Deficit/Hyperactivity Disorder (ADHD)       1.00      1.00      1.00         7
#                        Autism Spectrum Disorder       1.00      1.00      1.00         9
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Create the Random Forest model
random_forest_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# Train the model
random_forest_model.fit(X_train_tfidf, y_train)

print("✅ Random Forest trained successfully!")
# Out:
# ✅ Random Forest trained successfully!

# %%
# Predict diseases for the test data
rf_pred = random_forest_model.predict(X_test_tfidf)

print("✅ Predictions generated!")
# Out:
# ✅ Predictions generated!

# %%
from sklearn.metrics import accuracy_score

rf_accuracy = accuracy_score(y_test, rf_pred)

print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print(f"Random Forest Accuracy: {rf_accuracy * 100:.2f}%")
# Out:
# Random Forest Accuracy: 0.9146
# Random Forest Accuracy: 91.46%

# %%
from sklearn.metrics import classification_report

rf_report = classification_report(
    y_test,
    rf_pred,
    zero_division=0
)

print(rf_report)
# Out:
#                                                  precision    recall  f1-score   support
#
#     African Trypanosomiasis (Sleeping Sickness)       1.00      0.50      0.67         6
#                             Alzheimer's Disease       1.00      1.00      1.00        10
#                                      Amoebiasis       1.00      0.83      0.91         6
#                                Anorexia Nervosa       1.00      1.00      1.00         8
#                                         Anthrax       1.00      1.00      1.00         8
#                                      Ascariasis       1.00      0.78      0.88         9
#                                          Asthma       0.91      1.00      0.95        10
# Attention-Deficit/Hyperactivity Disorder (ADHD)       1.00      1.00      1.00         7
#                        Autism Spectrum Disorder       1.00      1.00      1.00         9
# ...
